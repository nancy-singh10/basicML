# %% [markdown]
# <a href="https://colab.research.google.com/github/nancy-singh10/basicML/blob/main/Diabetes_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Diabetes prediction ---Support Vector Machine

# %% [markdown]
# # **diabiatic data set   --> data pre processing --->train test data-->accuracy find (check)--->support vector machine model classifier-->  traied SVM **

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# # dATA COLLECTION AND analysis

# %%
dia=pd.read_csv("/content/diabetes.csv",header=None)

# %%
#pprinting the first 5 rows of thr dataset
dia.head()
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
# number of rows and col in this dataset
dia.shape
# Out:
# (769, 9)

# %%
dia.describe()
#stats
# Out:
#           0    1    2    3    4    5      6    7    8
# count   769  769  769  769  769  769    769  769  769
# unique   18  137   48   52  187  249    518   53    3
# top       1  100   70    0    0   32  0.254   22    0
# freq    135   17   57  227  374   13      6   72  500

# %%
dia[8].value_counts()
# Out:
# 8
# 0          500
# 1          268
# Outcome      1
# Name: count, dtype: int64

# %% [markdown]
# # 0==>Non -dia
# #1 --->dia

# %%
#separate data x y
X=dia.drop(columns=8,axis=1)
y=dia[8]

# %%
X
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7
# 0    DiabetesPedigreeFunction  Age
# 1                       0.627   50
# ...

# %%
y
# Out:
# 0      Outcome
# 1            1
# 2            0
# 3            1
# 4            0
#         ...
# 764          0
# 765          0
# 766          0
# 767          1
# 768          0
# Name: 8, Length: 769, dtype: object

# %% [markdown]
# # Data standard->why range is high difficult to work

# %%
scaler=StandardScaler()

# %%
print(X.dtypes)
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# dtype: object

# %%
X = X.apply(pd.to_numeric, errors='coerce')
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[        nan         nan         nan ...         nan         nan
#           nan]
#  [ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=X_scaled
y=dia[8]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (769, 8) (615, 8) (154, 8)

# %% [markdown]
# **Training data**

# %%
classifier=svm.SVC(kernel='linear')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load dataset
dia = pd.read_csv("/content/diabetes.csv", header=None)

# Print the first 5 rows of the dataset
print(dia.head())

# Separate features and labels
X = dia.drop(columns=8, axis=1)  # Drop the label column from features
y = dia[8]  # Label column

# Convert data to numeric, replacing non-numeric entries with NaN
X = X.apply(pd.to_numeric, errors='coerce')

# Fill NaN values with the mean of each column
X = X.fillna(X.mean())

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=2)

# Create an SVC classifier with a linear kernel
classifier = SVC(kernel='linear')

# Train the classifier
classifier.fit(X_train, y_train)
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -4.51201203e-16
#    0.00000000e+00  0.00000000e+00]
#  [ 6.40363757e-01  8.48875909e-01  1.49738143e-01 ...  2.04145549e-01
#    4.68796886e-01  1.42692348e+00]
#  [-8.45434930e-01 -1.12412750e+00 -1.60650235e-01 ... -6.84867388e-01
# ...

# %%
# Calculate accuracy on the training data
Xtrain_pred = classifier.predict(X_train)
training_acc = accuracy_score(y_train, Xtrain_pred)
print(f"Training accuracy: {training_acc}")
# Out:
# Training accuracy: 0.767479674796748

# %%
# Calculate accuracy on the test data
Xtest_pred = classifier.predict(X_test)
test_acc = accuracy_score(y_test, Xtest_pred)
print(f"Test accuracy: {test_acc}")
# Out:
# Test accuracy: 0.7922077922077922

# %% [markdown]
# making a predictable system

# %%
# Make predictions on the test data and calculate accuracy
y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Test accuracy: {accuracy}")
# Out:
# Test accuracy: 0.7922077922077922

# %%
# Input data
input_data = (2, 197, 70, 45, 543, 30.5, 0.158, 53)

# Convert the input data to a NumPy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we're predicting for one instance
input_reshape = input_data_as_numpy_array.reshape(1, -1)

# Standardize the input data
std_data = scaler.transform(input_reshape)
print(std_data)

# Make a prediction
prediction = classifier.predict(std_data)

# Output the prediction result
print("Prediction:", prediction)


if(prediction==0):
  print("person is not diabetic")
else:
  print("person is diabetic")
# Out:
# [[-0.54827519  2.38343412  0.04627535  1.53554927  4.0245395  -0.18956018
#   -0.94856063  1.68235288]]
# Prediction: ['1']
# person is diabetic
